# %%
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

print(cv2.__version__)
# Out:
# 4.1.2

# %% [markdown]
# ### Simple Thresholding

# %%
img = cv2.imread('gradient.png', 0)
_, thb =cv2.threshold(img, 125, 255, cv2.THRESH_BINARY)
_, thi =cv2.threshold(img, 125, 255, cv2.THRESH_BINARY_INV)
_, tht =cv2.threshold(img, 125, 255, cv2.THRESH_TRUNC)
_, thz =cv2.threshold(img, 125, 255, cv2.THRESH_TOZERO)
_, thzi =cv2.threshold(img, 125, 255, cv2.THRESH_TOZERO_INV)

cv2.imshow('image', img)
cv2.imshow('thb', thb)
cv2.imshow('thi', thi)
cv2.imshow('tht', tht)
cv2.imshow('thz', thz)
cv2.imshow('thzi', thzi)


cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
img = cv2.imread('gradient.png', 1)
_, thb =cv2.threshold(img, 125, 255, cv2.THRESH_BINARY)
_, thi =cv2.threshold(img, 125, 255, cv2.THRESH_BINARY_INV)
_, tht =cv2.threshold(img, 125, 255, cv2.THRESH_TRUNC)
_, thz =cv2.threshold(img, 125, 255, cv2.THRESH_TOZERO)
_, thzi =cv2.threshold(img, 125, 255, cv2.THRESH_TOZERO_INV)

titles= ['ORIGINAL','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images= [img, thb, thi, tht, thz, thzi]

for i in range(0,6):
    plt.subplot(2,3, i+1)
    plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]) , plt.yticks([])
plt.show()

# %% [markdown]
# ### Adaptive thresholding

# %%
img = cv2.imread('C:/Users/Windows 10/Desktop/DL/CV/opencv-master/samples/data/sudoku.png', 0)
_, thb =cv2.threshold(img, 125, 255, cv2.THRESH_BINARY)
ath =cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
athg =cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)


cv2.imshow('image', img)
cv2.imshow('thb', thb)
cv2.imshow('ath', ath)
cv2.imshow('athg', athg)


cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
img = cv2.imread('lena.jpg', 1)
cv2.imshow('image', img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.yticks([]), plt.xticks([])
plt.show()

cv2.waitKey(5000)
cv2.destroyAllWindows()

# %% [markdown]
# ### Marphological Transformation

# %%
img = cv2.imread('smarties.png', 0)  #cv2.IMREAD_GRAYSCALE
_, mask =cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)

kernal =np.ones((3,3), np.uint8)

dilation= cv2.dilate(mask, kernal, iterations=2)
erosion= cv2.erode(mask, kernal, iterations=2)
opening= cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernal)
close= cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernal)


titles= ['image', 'mask', 'dilation', 'erosion', 'opening', 'close']
images= [img, mask, dilation, erosion,  opening, close]

for i in range(6):
    #plt.figure(figsize=(5,8))
    plt.subplot(2,3, i+1)
    plt.imshow(images[i], 'gray')
    
    plt.title(titles[i])
    plt.xticks([]) , plt.yticks([])

plt.show()

# %%
img = cv2.imread('C:/Users/Windows 10/Desktop/DL/CV/opencv-master/samples/data/j.png', 0)  #cv2.IMREAD_GRAYSCALE
#_, mask =cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)

kernal =np.ones((3,3), np.uint8)

dilation= cv2.dilate(img, kernal, iterations=2)
erosion= cv2.erode(img, kernal, iterations=2)
opening= cv2.morphologyEx(img, cv2.MORPH_OPEN, kernal)
close= cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernal)


titles= ['image', 'mask', 'dilation', 'erosion', 'opening', 'close']
images= [img, img, dilation, erosion,  opening, close]

for i in range(6):
    #plt.figure(figsize=(5,8))
    plt.subplot(2,3, i+1)
    plt.imshow(images[i], 'gray')
    
    plt.title(titles[i])
    plt.xticks([]) , plt.yticks([])

plt.show()

# %% [markdown]
# ### Smoothing image

# %%
img = cv2.imread('opencv-logo.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

kernal = np.ones((5,5), np.float32)/25
dst = cv2.filter2D(img, -1, kernal)
blur = cv2.blur(img, (5,5))
gblur = cv2.GaussianBlur(img, (5,5) , 0)

titles= ['image', '2D covolution', 'blur', 'gblur']
images= [img, dst, blur, gblur]

for i in range(4):
    plt.subplot(1,4, i+1)
    plt.imshow(images[i], 'gray')
    
    plt.title(titles[i])
    plt.xticks([]) , plt.yticks([])

plt.show()

# %%
img = cv2.imread('water.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

kernal = np.ones((5,5), np.float32)/25
dst = cv2.filter2D(img, -1, kernal)
blur = cv2.blur(img, (5,5))
gblur = cv2.GaussianBlur(img, (5,5) , 0)
median = cv2.medianBlur(img, 5) # salt and pepper noise
bilateralFilter = cv2.bilateralFilter(img, 9, 75, 75)


titles= ['image', '2D covolution', 'blur', 'gblur', 'median', 'bilateralFilter']
images= [img, dst, blur, gblur, median, bilateralFilter]

for i in range(6):
    #plt.figure(figsize=(15,10))
    plt.subplot(2,3, i+1)
    plt.imshow(images[i], 'gray')
    
    plt.title(titles[i])
    plt.xticks([]) , plt.yticks([])

plt.show()

# %%
img = cv2.imread('lena.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

kernal = np.ones((5,5), np.float32)/25
dst = cv2.filter2D(img, -1, kernal)
blur = cv2.blur(img, (5,5))
gblur = cv2.GaussianBlur(img, (5,5) , 0)
median = cv2.medianBlur(img, 5) # salt and pepper noise
bilateralFilter = cv2.bilateralFilter(img, 9, 75, 75) # effective in noise removal while keeping edge 


titles= ['image', '2D covolution', 'blur', 'gblur', 'median', 'bilateralFilter']
images= [img, dst, blur, gblur, median, bilateralFilter]

for i in range(6):
    #plt.figure(figsize=(15,10))
    plt.subplot(2,3, i+1)
    plt.imshow(images[i], 'gray')
    
    plt.title(titles[i])
    plt.xticks([]) , plt.yticks([])

plt.show()

# %% [markdown]
# ### Image Gradients

# %%
img = cv2.imread('messi5.jpg', cv2.IMREAD_GRAYSCALE)

lap = cv2.Laplacian(img, cv2.CV_64F, ksize=1)
lap = np.uint8(np.absolute(lap))

sobelx =cv2.Sobel(img, cv2.CV_64F, 1, 0)
sobely =cv2.Sobel(img, cv2.CV_64F, 0, 1)

sobelx = np.uint8(np.absolute(sobelx))
sobely = np.uint8(np.absolute(sobely))

sobelcombined =cv2.bitwise_or(sobelx, sobely)

canny =cv2.Canny(img, 100, 200)

titles= ['image', 'Laplacian', 'sobelx', 'sobely', 'sobelcombined', 'canny']
images= [img, lap, sobelx, sobely, sobelcombined, canny]

for i in range(6):
    plt.figure(figsize=(15,10))
    plt.subplot(2,3, i+1)
    plt.imshow(images[i], 'gray')
    
    plt.title(titles[i])
    plt.xticks([]) , plt.yticks([])

plt.show()

# %%
img = cv2.imread('C:/Users/Windows 10/Desktop/DL/CV/opencv-master/samples/data/sudoku.png', cv2.IMREAD_GRAYSCALE)

lap = cv2.Laplacian(img, cv2.CV_64F, ksize=1)
lap = np.uint8(np.absolute(lap))

sobelx =cv2.Sobel(img, cv2.CV_64F, 1, 0)
sobely =cv2.Sobel(img, cv2.CV_64F, 0, 1)

sobelx = np.uint8(np.absolute(sobelx))
sobely = np.uint8(np.absolute(sobely))

sobelcombined =cv2.bitwise_or(sobelx, sobely)

titles= ['image', 'Laplacian', 'sobelx', 'sobely', 'sobelcombined']
images= [img, lap, sobelx, sobely, sobelcombined]


for i in range(5):
    #plt.figure(figsize=(15,10))
    plt.subplot(2,3, i+1)
    plt.imshow(images[i], 'gray')
    
    plt.title(titles[i])
    plt.xticks([]) , plt.yticks([])

plt.show()

# %% [markdown]
# ### Canny Edge Detection

# %%
img = cv2.imread('messi5.jpg', cv2.IMREAD_GRAYSCALE)

canny =cv2.Canny(img, 100, 200)

titles= ['image', 'canny']
images= [img, canny]

for i in range(2):
    plt.figure(figsize=(15,10))
    plt.subplot(1,2, i+1)
    plt.imshow(images[i], 'gray')
    
    plt.title(titles[i])
    plt.xticks([]) , plt.yticks([])

plt.show()
